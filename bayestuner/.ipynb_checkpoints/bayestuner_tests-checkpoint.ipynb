# %%
from acquisitionfunc import UCB, EI
from Bounds import Bound, Bounds
from optimizer import DifferentialEvolution
from bayestuner import BayesTuner
import numpy as np
import pandas as pd
import os
from sklearn.cluster import KMeans
from sklearn.metrics import adjusted_rand_score
import matplotlib.pyplot as plt
from sklearn.mixture import GaussianMixture
import numpy as np
import seaborn as sns
# %matplotlib notebook
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-1fb85a4145f4> in <module>
#       1 from acquisitionfunc import UCB, EI
# ----> 2 from Bounds import Bound, Bounds
#       3 from optimizer import DifferentialEvolution
#       4 from bayestuner import BayesTuner
#       5 import numpy as np
#
# ModuleNotFoundError: No module named 'Bounds'

# %%
def getLabelsfromGT(X,ground_truth):
    truelabels = []
    Labels = {i: ground_truth[i] for i in range(len(ground_truth))}
    def getClosestCentroid(x,ground_truth):
        d = {np.linalg.norm(x-Labels[i]): i  \
            for i in range(len(ground_truth))}
        return d[min(d.keys())]
    for point in X:
        truelabels.append(getClosestCentroid(point,ground_truth))
    return truelabels

# %% [markdown]
# # Dataset generation

# %%
#first dataset : very overlapped
df1 = pd.read_csv("../bopt/s4.csv",delimiter =";")
gt1 = pd.read_csv("../bopt/s4_gt.csv",delimiter =";")
centroids = gt1.values
N_samples_per_centroid = 400
labels = {i : centroids[i] for i in range(len(centroids))}
gmm = GaussianMixture(n_components = 15, covariance_type = 'full').fit(df1.values)
covariances = gmm.covariances_

# %%
data_gen = lambda i : np.random.multivariate_normal(centroids[i],covariances[i],N_samples_per_centroid)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
colors = ['blue','orange','green','red','purple','brown','pink','gray','olive','cyan','deepskyblue','orchid','chartreuse','chocolate','steelblue']
data = np.hstack((data_gen(0),np.array([0]*N_samples_per_centroid).reshape(-1,1)))
fig4 = plt.figure()
plt.plot(data[:,0],data[:,1],'o',color = colors[0],markersize = 2)

for i in range(1,len(centroids)):
    data_ = np.hstack((data_gen(i),np.array([i]*N_samples_per_centroid).reshape(-1,1)))
    plt.plot(data_[:,0],data_[:,1],'o',color = colors[i],markersize = 2)
    data = np.vstack((data,data_))
plt.plot(centroids[:,0],centroids[:,1],'kD',markersize = 6,label = "Ground Truth Centroids")

KM = KMeans(n_clusters = 15, random_state = 0).fit(training_data)

plt.plot(KM.cluster_centers_[:,0],KM.cluster_centers_[:,1],'rD',markersize = 4,label = "Predicted Centroids")
plt.legend()
# Out:
# <img src="data:image/png;base64,..." width="980">

# %%
training_data = data.T[:2].T
GMM = GaussianMixture(n_components = 15, covariance_type = 'full').fit(training_data)
pred_labels = GMM.predict(training_data)
print(adjusted_rand_score(pred_labels,data[:,2]))

obj4 = lambda i : adjusted_rand_score(data[:,2],
                        GaussianMixture(n_components = i[0], covariance_type = 'full').fit(training_data).predict(training_data))

obj5 = lambda i : adjusted_rand_score(data[:,2],
                        KMeans(n_clusters = i[0], random_state = 0).fit(training_data).labels_)

opts = []
for i in range(10):
    tuner = BayesTuner(objective = obj5, bounds = bounds,num_iter = 25, num_samples = 5)
    opts.append(tuner.tune())
# Out:
# 0.7512012843231358

# %%
opti_ = [x[0] for x in opts]
figuren, ax = plt.subplots(nrows = 1, ncols =2)
x = np.random.uniform(0,10,100)
sns.distplot(opti_,kde = False, ax = ax[0])
ax[0].set_title("Histogram of the results")
x = range(len(bayestuner.past_evals))
ax[1].plot(range(len(tuner.past_evals)),tuner.past_evals,'r')
ax[1].set_xlabel("Iterations")
ax[1].set_ylabel("Objective")
ax[1].set_xlim(0,30)
ax[1].set_title("Value vs Iteration")
plt.xlabel("Optimums")
ax[0].set_xlim(14,20)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="933">
# /anaconda3/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
from sklearn.cluster import Birch

birch = Birch(threshold=0.5, branching_factor=50, n_clusters=3).fit(training_data)

obj6 = lambda x : adjusted_rand_score(data[:,2],
                        Birch(threshold=x[0], branching_factor=int(x[1]), n_clusters=int(x[2])).fit(training_data).labels_)

bounds_ = [Bound([0,1],"continuous"),Bound([2,50],"discrete"),Bound([2,50],"discrete")]

bayestuner3 = BayesTuner(objective = obj6,
                         bounds = bounds_,
                         num_iter = 40,
                         num_samples = 15)


opt = bayestuner3.tune(print_score = True)
# Out:
# current eval : [0.2164168769571737, 4, 5] / score : 0.3442149801136402
# current eval : [0.0, 49, 9] / score : 0.5147481307839192
# current eval : [0.9495077993564545, 50, 50] / score : 0.4137757943495103
# current eval : [1.0, 32, 20] / score : 0.6815165788870926
# current eval : [1.0, 33, 19] / score : 0.6920666269583574
# current eval : [1.0, 33, 18] / score : 0.7033025538436296
# current eval : [1.0, 50, 2] / score : 0.11355973514642347
# current eval : [-1.3877787807814457e-17, 24, 23] / score : 0.6719825701930212
# current eval : [1.0, 2, 27] / score : 0.6124439684476931
# current eval : [1.0, 2, 50] / score : 0.4137757943495103
# current eval : [1.0, 21, 25] / score : 0.6389259179823441
# current eval : [0.0, 50, 25] / score : 0.6389259179823441
# current eval : [0.0, 2, 26] / score : 0.6146894285710839
# current eval : [1.0, 50, 25] / score : 0.6389259179823441
# current eval : [0.0, 32, 19] / score : 0.6920666269583574
# ...

# %%
fig20 = plt.figure()
plt.title("Evaluations of BIRCH")
plt.plot(bayestuner3.past_evals,'k')
plt.xlabel("Iteration")
plt.ylabel("Birch Evaluations")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# Out:
# <img src="data:image/png;base64,..." width="969">

# %% [markdown]
# # First clustering dataset

# %%
df = pd.read_csv("../bopt/clustering.csv",delimiter =";")
gt = pd.read_csv("../bopt/groundtruth.csv",delimiter =";")
figure1 = plt.figure()
plt.title("Clustering dataset")
plt.plot(df.values[:,0],df.values[:,1],'ko',markersize = 1)
plt.plot(gt.values[:,0],gt.values[:,1],'ro',markersize = 1)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="843">

# %%
gmm1 = GaussianMixture(n_components = 15, covariance_type = 'full').fit(df.values)
plt.plot(gmm1.means_[:,0],gmm1.means_[:,1],'bD')
print(gmm1.predict(df1.values))
print(gmm1.bic(df.values))
# Out:
# [ 7  7  9 ...  7 13 13]
# 260753.9338898823

# %% [markdown]
# # KMEANS

# %%
realLabels = getLabelsfromGT(df.values,gt.values)


obj = lambda i : adjusted_rand_score(realLabels,
                                     KMeans(n_clusters = i[0],random_state=0).fit(df.values).labels_)

bounds = [Bound([2,50],"discrete")]
optimums = []
for i in range(10):
    bayestuner = BayesTuner(objective = obj, bounds = bounds, num_iter = 25,
                            num_samples = 5)
    optimums.append(bayestuner.tune())

# %%
optimum_ = [x[0] for x in optimums]
figuren, ax = plt.subplots(nrows = 1, ncols =2)
x = np.random.uniform(0,10,100)
sns.distplot(optimum_,kde = False, ax = ax[0])
ax[0].set_title("Histogram of the results")
x = range(len(bayestuner.past_evals))
ax[1].plot(range(len(bayestuner.past_evals)),bayestuner.past_evals)
ax[1].set_xlabel("Iterations")
ax[1].set_ylabel("Objective")
ax[1].set_xlim(0,30)
ax[1].set_title("Value vs Iteration")
plt.xlabel("Optimums")
ax[0].set_xlim(14,17)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="901">

# %% [markdown]
# # Second clustering dataset

# %%
df1 = pd.read_csv("../bopt/s4.csv",delimiter =";")
gt1 = pd.read_csv("../bopt/s4_gt.csv",delimiter =";")
figure = plt.figure()
clf = KMeans(n_clusters = 15,random_state = 0).fit(df1.values)

plt.plot(df1.values[:,0],df1.values[:,1],'ko',markersize = 1)
plt.plot(gt1.values[:,0],gt1.values[:,1],'ro',markersize = 5)
plt.plot(clf.cluster_centers_[:,0],clf.cluster_centers_[:,1],'bD',markersize = 3)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
realLabels2 = getLabelsfromGT(df1.values,gt1.values)

obj2 = lambda i : adjusted_rand_score(realLabels2,
                                     KMeans(n_clusters = i[0],random_state=0).fit(df1.values).labels_)
bayestuner = BayesTuner(objective = obj2, bounds = bounds, num_iter = 25,
                        num_samples = 5)
print(bayestuner.tune(print_score = True))
# Out:
# current eval : [28] / score : 0.707906748647986
# current eval : [2] / score : 0.12170634041203483
# current eval : [21] / score : 0.813303385626543
# current eval : [20] / score : 0.808927193385375
# current eval : [21] / score : 0.813303385626543
# current eval : [20] / score : 0.808927193385375
# current eval : [21] / score : 0.813303385626543
# current eval : [20] / score : 0.808927193385375
# current eval : [23] / score : 0.7860052095627189
# current eval : [50] / score : 0.5090736981847346
# current eval : [19] / score : 0.8376031232150837
# current eval : [25] / score : 0.7663456964315633
# current eval : [18] / score : 0.8449726150352609
# current eval : [17] / score : 0.87605160395043
# current eval : [17] / score : 0.87605160395043
# current eval : [16] / score : 0.8911622161878169
# current eval : [16] / score : 0.8911622161878169
# current eval : [16] / score : 0.8911622161878169
# current eval : [15] / score : 0.9195764082097713
# ...

# %% [markdown]
# # GMM

# %%
gmm = GaussianMixture(n_components = 15, covariance_type = 'full').fit(df1.values)
fig3 = plt.figure()
print(gmm.covariances_)
plt.plot(df1.values[:,0],df1.values[:,1],'ko',markersize = 1, label = "Data")
plt.plot(gt1.values[:,0],gt1.values[:,1],'ro',markersize = 5,label = "groundtruth")
plt.plot(gmm.means_[:,0],gmm.means_[:,1],'bD',markersize = 3,label = "GMM preds")
plt.title(f"Score : {gmm.score(df1.values)}")
plt.legend()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
# [[[ 2.26584279e+09 -8.91144231e+08]
#   [-8.91144231e+08  2.42751766e+09]]
#
#  [[ 5.91485449e+09  9.93975246e+08]
#   [ 9.93975246e+08  2.48128919e+09]]
#
#  [[ 7.35431712e+08 -2.24501561e+08]
#   [-2.24501561e+08  1.14424353e+09]]
#
#  [[ 1.31343937e+09  3.65915178e+08]
#   [ 3.65915178e+08  1.67944795e+09]]
#
#  [[ 3.14570577e+09 -6.40004600e+08]
#   [-6.40004600e+08  3.09571193e+09]]
#
#  [[ 1.83067535e+09  1.18222351e+08]
#   [ 1.18222351e+08  1.49949251e+09]]
#
#  [[ 4.78141781e+09  2.30141872e+09]
#   [ 2.30141872e+09  4.35209961e+09]]
#
#  [[ 1.83504569e+09 -6.13713317e+08]
#   [-6.13713317e+08  3.56290339e+08]]
#
#  [[ 1.86953367e+09 -1.30552033e+09]
#   [-1.30552033e+09  4.05242477e+09]]
#
#  [[ 5.11618390e+09 -9.10974623e+07]
#   [-9.10974623e+07  2.72472796e+09]]
#
#  [[ 1.98685833e+08  3.14774528e+08]
#   [ 3.14774528e+08  7.72971053e+08]]
#
#  [[ 5.27276872e+08 -2.10060053e+07]
#   [-2.10060053e+07  1.54845620e+07]]
#
# ...

# %%
obj3 = lambda i:  GaussianMixture(n_components = i[0],covariance_type = 'full').fit(df1.values).bic(df1.values)
bayestuner2 = BayesTuner(objective = obj3, bounds = bounds, num_iter = 25, num_samples = 5, alpha = 1e-1)
print(bayestuner2.tune(print_score = True))
# Out:
# current eval : [36] / score : 264569.7117367588
# current eval : [16] / score : 264052.0074926957
# current eval : [34] / score : 264423.59811748547
# current eval : [23] / score : 264259.54143200646
# current eval : [2] / score : 268886.66292170953
# current eval : [2] / score : 268886.66292170953
# current eval : [2] / score : 268886.616163221
# current eval : [2] / score : 268886.66292170953
# current eval : [2] / score : 268886.66292170953
# current eval : [2] / score : 268886.616163221
# current eval : [2] / score : 268886.66292170953
# current eval : [2] / score : 268886.616163221
# current eval : [2] / score : 268886.66292170953
# current eval : [2] / score : 268886.616163221
# current eval : [2] / score : 268886.66292170953
# ...

# %% [markdown]
# # Optimization of multi modal functions

# %%
import math
rastringin_ = lambda X : -(10*len(X) + sum([x**2 - 10*np.cos(2*math.pi*x) for x in X]))
dim = 2
bounds = [Bound([-5.12,5.12],"continuous") for i in range(dim)]

# %%
from optimizer import LocalOptimizer

print(rastringin_([0,0]))
tuner = BayesTuner(objective = rastringin_, 
                   bounds = bounds,
                   num_iter = 70,
                   acquisition = lambda i : EI(i,None),
                   num_samples = 50,
                   alpha = 1e-1)

optimal = tuner.tune()
# Out:
# -0.0

# %%
fig300 = plt.figure()
plt.plot(tuner.past_hyper[:,0],tuner.past_hyper[:,1],'bo',markersize = 3)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="320">

# %%
def ackley(X,a=20, b=0.2, c=2*np.pi):
    d           =len(X)
    sum_sq_term = -a * np.exp(-b * np.sqrt(sum(X[i]**2 for i in range(d))/d))
    cos_term    = -np.exp(sum(np.cos(c*X[i])/d for i in range(d)))
    return a + np.exp(1) + sum_sq_term + cos_term


ackley_ = lambda X : - ackley(X)

# %%
dim = 2
bounds = [Bound([-10,10],"continuous") for i in range(dim)]

tuner1 = BayesTuner(objective = ackley_,
                    bounds = bounds,
                    num_iter = 40,
                    num_samples = 10,
                    alpha = 1e-1)

optimal_ = tuner1.tune()
print(optimal_)
print(ackley_(optimal_))
# Out:
# [-0.27822677 -0.05176244]
# -2.032462803789955

# %%
fig100 = plt.figure()
plt.plot(tuner1.past_hyper[:,0],tuner1.past_hyper[:,1],'bo',markersize = 3)
# Out:
# <img src="data:image/png;base64,..." width="320">

# %% [markdown]
# # DBSCAN DATA ANTHONY

# %%
from sklearn.cluster import DBSCAN
import time

df = pd.read_csv("reduced_data_yazid.csv",delimiter=",")

df_ = np.delete(df.values,-1,1)

# %%
def adjusted_rand(X): 
    res = None
    try: 
        res = adjusted_rand_score(DBSCAN(eps=X[0], min_samples=X[1], 
                              metric="euclidean", metric_params=None, 
                              algorithm="auto", leaf_size=X[2], 
                              p=None, n_jobs=None).fit(df_).labels_,df.values.T[-1:][0])
    except:
        res = -1
    return res
objective = lambda X : adjusted_rand(X)

bounds = [Bound([0.40,0.60],"continuous"),Bound([2,200],"discrete"),Bound([2,200],"discrete")]

tuner = BayesTuner(objective = objective,
                   bounds = bounds,
                   num_iter = 30,
                   num_samples = 15)

# %%
optim = tuner.tune()

# %%
optimal_hyper = tuner.tune(print_score = True)
print(objective(optimal_hyper))
# Out:
# current eval : [2.151130224372991, 29, 126] / score : 0.0
# current eval : [0.5477747436529117, 288, 155] / score : 0.44705780845774756
# current eval : [0.5153569483819347, 288, 156] / score : 0.40942114436609933
# current eval : [0.48701031599602995, 290, 160] / score : 0.3837959970604711
# current eval : [1.097899348156661, 279, 160] / score : -0.00879266312158738
# current eval : [0.4177436492746814, 291, 155] / score : 0.27612922783357735
# current eval : [3.0, 288, 157] / score : 0.0
# current eval : [0.0, 289, 157] / score : -1
# current eval : [1.2160441353907196, 293, 165] / score : -0.003651542971670375
# current eval : [1.3509953648541135, 289, 163] / score : -0.0005659347051425709
# current eval : [0.5427862669607834, 287, 152] / score : 0.4387213494117262
# current eval : [0.22511505385797737, 295, 158] / score : 0.1983141814779568
# current eval : [0.7433239746086423, 294, 157] / score : -0.02402381317695411
# ...

# %%
second_optimal = tuner.tune(print_score = True)
print(objective(second_optimal))
# Out:
# current eval : [0.7484609711719133, 149, 181] / score : -0.019413222843587187
# current eval : [0.4757704484326754, 170, 155] / score : 0.4462356446112934
# current eval : [0.3624287328377899, 101, 162] / score : 0.32625471816952106
# current eval : [0.3399792277521195, 91, 13] / score : 0.29993914713367503
# current eval : [0.9284264351024099, 90, 199] / score : -0.0075218758710540005
# current eval : [0.7621267357991769, 35, 14] / score : -0.008336250838556837
# current eval : [0.6129874777348984, 188, 40] / score : -0.01946690802112217
# current eval : [0.78536633707622, 122, 26] / score : -0.016290788467892163
# current eval : [0.6405905456453349, 122, 23] / score : -0.013764910466619875
# current eval : [0.24981979536514476, 79, 46] / score : 0.151338508412145
# current eval : [0.9646741621485577, 158, 89] / score : -0.010027042462806387
# current eval : [0.0654612885393886, 95, 44] / score : -0.04220004499026456
# ...

# %%
print(f"optimal hyperparemeter found : {second_optimal}")
# Out:
# optimal hyperparemeter found : [  0.53989782 118.          21.        ]

# %%
dbscan = lambda X : DBSCAN(eps=X[0], min_samples=X[1], 
                              metric="euclidean", metric_params=None, 
                              algorithm="auto", leaf_size=X[2], 
                              p=None, n_jobs=None).fit(df_)

final_db = dbscan(second_optimal)

# %%
print(f"number of clusters : {set(final_db.labels_)}")
# Out:
# number of clusters : {0, 1, -1}

# %%
clusters_size = {i : list(final_db.labels_).count(i) for i in set(final_db.labels_)}
print(f"size of each cluster : {clusters_size}")
# Out:
# size of each cluster : {0: 18359, 1: 1070, -1: 569}

# %%
from sklearn.metrics.cluster import contingency_matrix


print(f"contingency matrix : \n {contingency_matrix(df.values.T[-1:],final_db.labels_)}")
# Out:
# contingency matrix :
#  [[  558 18333   129]
#  [   11    26   941]]

# %%
colors = ['gold','turquoise','mediumorchid']

clusters = [[df_[i] for i in range(len(df_)) if final_db.labels_[i] == j] for j in set(final_db.labels_)]

# %%
new_fig = plt.figure()

for i in range(3):
    plt.plot([clusters[i][j][0] for j in range(len(clusters[i]))],
             [clusters[i][j][1] for j in range(len(clusters[i]))],
             'o',color = colors[i],markersize = 1,label = f"{list(set(final_db.labels_))[i]}")

plt.xlabel("X1")
plt.ylabel("X2")
plt.legend()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="320">

# %% [markdown]
# # Optimisation SILHOUETTE

# %%
from sklearn.metrics import silhouette_score
from sklearn.metrics import davies_bouldin_score

def davies_bould(X):
    res = None
    try :
        res = davies_bouldin_score (df_,DBSCAN(eps=X[0], min_samples=X[1], 
                                           metric="euclidean", metric_params=None, 
                                           algorithm="auto", leaf_size=X[2], 
                                           p=None, n_jobs=None).fit(df_).labels_)
    except: 
       res = 1000
    return res


davies_bouldin = lambda X : -davies_bould(X)

bounds_silh = [Bound([0,1],"continuous"),Bound([2,200],"discrete"),Bound([2,200],"discrete")]

bouldin_tuner = BayesTuner(objective = davies_bouldin,
                              bounds = bounds_silh,
                              num_samples = 15,
                              num_iter = 30)
# Out:
# /anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/unsupervised.py:342: RuntimeWarning: divide by zero encountered in true_divide
#   score = (intra_dists[:, None] + intra_dists) / centroid_distances
# /anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/unsupervised.py:342: RuntimeWarning: divide by zero encountered in true_divide
#   score = (intra_dists[:, None] + intra_dists) / centroid_distances
# /anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/unsupervised.py:342: RuntimeWarning: divide by zero encountered in true_divide
#   score = (intra_dists[:, None] + intra_dists) / centroid_distances
# /anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/unsupervised.py:342: RuntimeWarning: divide by zero encountered in true_divide
#   score = (intra_dists[:, None] + intra_dists) / centroid_distances
# /anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/unsupervised.py:342: RuntimeWarning: divide by zero encountered in true_divide
# ...

# %%
print(bouldin_tuner.past_evals)
# Out:
# [[-1.60999383]
#  [-1.78725596]
#  [-1.4199194 ]
#  [-1.44828615]
#  [-1.59962027]
#  [-1.8655174 ]
#  [-2.02031797]
#  [-1.41840575]
#  [-1.73017308]
#  [-1.95263931]
#  [-1.01411925]
#  [-1.46174301]
#  [-1.74335348]
#  [-1.4954487 ]
#  [-1.36151706]]

# %%
optimal_bouldin = bouldin_tuner.tune(print_score = True)
# Out:
# /anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/unsupervised.py:342: RuntimeWarning: divide by zero encountered in true_divide
#   score = (intra_dists[:, None] + intra_dists) / centroid_distances
# current eval : [0.37481041478326194, 198, 133] / score : -2.003512289897968
# current eval : [0.0, 200, 2] / score : -1000
# /anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/unsupervised.py:342: RuntimeWarning: divide by zero encountered in true_divide
#   score = (intra_dists[:, None] + intra_dists) / centroid_distances
# current eval : [0.820052577225933, 155, 87] / score : -1.3535101750370697
# /anaconda3/lib/python3.7/site-packages/sklearn/metrics/cluster/unsupervised.py:342: RuntimeWarning: divide by zero encountered in true_divide
#   score = (intra_dists[:, None] + intra_dists) / centroid_distances
# current eval : [1.0, 38, 2] / score : -0.9892783481982943
# ...

# %%
db_bouldin = dbscan(optimal_bouldin)
print(db_bouldin.labels_)
# Out:
# [0 0 0 ... 0 1 0]

# %%
set(db_bouldin.labels_)
# Out:
# {-1, 0, 1}

# %%
colors = ['gold','turquoise','mediumorchid']

clusters = [[df_[i] for i in range(len(df_)) if db_bouldin.labels_[i] == j] for j in set(db_bouldin.labels_)]

# %%
new_fig1 = plt.figure()

for i in range(3):
    plt.plot([clusters[i][j][0] for j in range(len(clusters[i]))],
             [clusters[i][j][1] for j in range(len(clusters[i]))],
             'o',color = colors[i],markersize = 1,label = f"{list(set(final_db.labels_))[i]}")

plt.xlabel("X1")
plt.ylabel("X2")
plt.legend()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
clusters_size = {i : list(db_bouldin.labels_).count(i) for i in set(db_bouldin.labels_)}
print(f"size of each cluster : {clusters_size}")
# Out:
# size of each cluster : {0: 19917, 1: 71, -1: 10}

# %% [markdown]
# # Silhouette score

# %%
from sklearn.metrics import silhouette_score

def silh(X):
    res = None
    try: 
        res = silhouette_score(df_,DBSCAN(eps=X[0], min_samples=X[1], 
                                           metric="euclidean", metric_params=None, 
                                           algorithm="auto", leaf_size=X[2], 
                                           p=None, n_jobs=None).fit(df_).labels_)
    except: 
        res = -10
    return res 
        

silhouette = lambda X : silh(X)

bounds_silhouette = [Bound([0,3],"continuous"),Bound([2,300],"discrete"),Bound([2,300],"discrete")]

silhouette_tuner = BayesTuner(objective = silh,
                              bounds = bounds_silhouette,
                              num_samples = 15,
                              num_iter = 50)

# %%
optimal = silhouette_tuner.tune(print_score = True)
# Out:
# current eval : [2.9616561366025085, 40, 287] / score : -10
# current eval : [1.8658256138274285, 268, 11] / score : 0.661560971518776
# current eval : [0.0, 64, 195] / score : -10
# current eval : [0.8815655117256775, 221, 172] / score : 0.4231094279735412
# current eval : [0.0, 186, 175] / score : -10
# current eval : [1.299606470983953, 250, 152] / score : 0.6015552676692276
# current eval : [2.5261685768175033, 32, 57] / score : -10
# current eval : [2.503147403792869, 286, 159] / score : -10
# current eval : [2.2585048731984116, 239, 81] / score : -10
# current eval : [0.15617261993965093, 286, 108] / score : -0.042688203699193634
# current eval : [0.5211615741287566, 200, 248] / score : 0.06603206461473354
# current eval : [0.0, 212, 280] / score : -10
# current eval : [2.597554338734913, 265, 12] / score : -10
# current eval : [2.466848653863236, 96, 179] / score : -10
# current eval : [1.5580117261119266, 292, 224] / score : 0.661560971518776
# ...

# %%
optimal
# Out:
# array([  2.0089654, 257.       , 145.       ])

# %%
db_silhouette = dbscan(optimal)

# %%
set(db_silhouette.labels_)
# Out:
# {-1, 0}

# %%
clusters_size = {i : list(db_silhouette.labels_).count(i) for i in set(db_silhouette.labels_)}
print(f"size of each cluster : {clusters_size}")
# Out:
# size of each cluster : {0: 19997, -1: 1}

# %%
clusters = [[df_[i] for i in range(len(df_)) if db_silhouette.labels_[i] == j] for j in set(db_silhouette.labels_)]

# %%
i = 0 
while db_silhouette.labels_[i] != -1:
    i+= 1
    
print(i)
print(df_[i])
# Out:
# 6036
# [-1.483353   -1.98692284 -0.42013454  0.35163538 -1.08066526 -0.73453781
#  -1.87924111  0.54108603 -0.11074489 -0.29352586 -1.1516351   1.29057475
#  -0.27261465  0.31133054  0.38281249  0.34902891  0.5134604  -0.07864848]

# %%
new_fig1 = plt.figure()

for i in range(2):
    plt.plot([clusters[i][j][0] for j in range(len(clusters[i]))],
             [clusters[i][j][1] for j in range(len(clusters[i]))],
             'o',color = colors[i],markersize = 1,label = f"{list(set(db_silhouette.labels_))[i]}")

plt.xlabel("X1")
plt.ylabel("X2")
plt.legend()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1045">
