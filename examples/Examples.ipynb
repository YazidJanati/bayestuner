# %%
#from bayestuner.benchmark_functions import *
import numpy as np
from bayestuner.tuner import BayesTuner
from bayestuner.bounds import Bound
import math

# %%
rastringin_ = lambda X : -(10*len(X) + sum([x**2 - 10*np.cos(2*math.pi*x) for x in X]))

# %%
tuner1 = BayesTuner(objective = rastringin_,
                    bounds = [Bound([-5.12,5.12],'continuous')],
                    n_iter = 60,
                    init_samples = 15)
result = tuner1.tune(print_score = True)
# Out:
# 0 / 60 | current eval : [4.283430648883972] / score : -30.432875542466657 |
#  -> best score yet: [-4.14025925]
# 1 / 60 | current eval : [2.9264466239930935] / score : -9.613128187154384 |
#  -> best score yet: [-4.14025925]
# 2 / 60 | current eval : [-1.9612039317671002] / score : -4.1419543382555375 |
#  -> best score yet: [-4.14025925]
# 3 / 60 | current eval : [-1.9611841563312036] / score : -4.142176737608385 |
#  -> best score yet: [-4.14025925]
# 4 / 60 | current eval : [-1.9611722181992206] / score : -4.142311069638906 |
#  -> best score yet: [-4.14025925]
# 5 / 60 | current eval : [1.8222765388261681] / score : -8.933913155520564 |
#  -> best score yet: [-4.14025925]
# 6 / 60 | current eval : [-1.9611653350250187] / score : -4.142388546463604 |
#  -> best score yet: [-4.14025925]
# 7 / 60 | current eval : [-1.9611576564167685] / score : -4.142474998201926 |
#  -> best score yet: [-4.14025925]
# 8 / 60 | current eval : [-1.9611516725968403] / score : -4.142542384437441 |
#  -> best score yet: [-4.14025925]
# 9 / 60 | current eval : [-1.9611464948348691] / score : -4.142600704453038 |
#  -> best score yet: [-4.14025925]
# 10 / 60 | current eval : [-1.961142319905148] / score : -4.142647736528775 |
#  -> best score yet: [-4.14025925]
# 11 / 60 | current eval : [-1.9611409522710659] / score : -4.142663144875079 |
#  -> best score yet: [-4.14025925]
# 12 / 60 | current eval : [-1.9611387461348286] / score : -4.142688001660726 |
#  -> best score yet: [-4.14025925]
# 13 / 60 | current eval : [-1.9611328441976332] / score : -4.1427545086658615 |
#  -> best score yet: [-4.14025925]
# 14 / 60 | current eval : [2.9281524832181454] / score : -9.575840657736393 |
#  -> best score yet: [-4.14025925]
# 15 / 60 | current eval : [-1.961132078191626] / score : -4.14276314152111 |
#  -> best score yet: [-4.14025925]
# 16 / 60 | current eval : [-1.961123250317277] / score : -4.142862647597415 |
#  -> best score yet: [-4.14025925]
# 17 / 60 | current eval : [-1.961114886082891] / score : -4.142956955300498 |
#  -> best score yet: [-4.14025925]
# 18 / 60 | current eval : [-1.9611242333562469] / score : -4.142851565489279 |
#  -> best score yet: [-4.14025925]
# 19 / 60 | current eval : [-1.9611215772971284] / score : -4.142881508936389 |
#  -> best score yet: [-4.14025925]
# 20 / 60 | current eval : [1.822261625636123] / score : -8.934700873874558 |
#  -> best score yet: [-4.14025925]
# 21 / 60 | current eval : [-1.9611210545005737] / score : -4.14288740307509 |
#  -> best score yet: [-4.14025925]
# 22 / 60 | current eval : [2.9293708038678212] / score : -9.549846016482524 |
#  -> best score yet: [-4.14025925]
# 23 / 60 | current eval : [1.8222602892424744] / score : -8.93477146441655 |
#  -> best score yet: [-4.14025925]
# 24 / 60 | current eval : [1.822255816342653] / score : -8.935007732722667 |
#  -> best score yet: [-4.14025925]
# 25 / 60 | current eval : [-1.9611241995333193] / score : -4.142851946779621 |
#  -> best score yet: [-4.14025925]
# 26 / 60 | current eval : [-1.9611200312645471] / score : -4.142898939597738 |
#  -> best score yet: [-4.14025925]
# 27 / 60 | current eval : [1.8222544585578284] / score : -8.935079454566292 |
#  -> best score yet: [-4.14025925]
# 28 / 60 | current eval : [-1.9611192858399202] / score : -4.142907344176547 |
#  -> best score yet: [-4.14025925]
# 29 / 60 | current eval : [-1.9611225119768048] / score : -4.1428709713869685 |
#  -> best score yet: [-4.14025925]
# 30 / 60 | current eval : [-1.9611183512575139] / score : -4.1429178817903285 |
#  -> best score yet: [-4.14025925]
# 31 / 60 | current eval : [1.8222429853705082] / score : -8.935685512046255 |
#  -> best score yet: [-4.14025925]
# 32 / 60 | current eval : [1.82224959917143] / score : -8.935336143061441 |
#  -> best score yet: [-4.14025925]
# 33 / 60 | current eval : [2.9299362092249717] / score : -9.537962955044696 |
#  -> best score yet: [-4.14025925]
# 34 / 60 | current eval : [1.8222492483453956] / score : -8.935354674986515 |
#  -> best score yet: [-4.14025925]
# 35 / 60 | current eval : [2.9303415221489835] / score : -9.529515178939079 |
#  -> best score yet: [-4.14025925]
# 36 / 60 | current eval : [-1.9611183593137675] / score : -4.1429177909529304 |
#  -> best score yet: [-4.14025925]
# 37 / 60 | current eval : [-1.9611187929750635] / score : -4.142912901289858 |
#  -> best score yet: [-4.14025925]
# 38 / 60 | current eval : [-1.9611378032527667] / score : -4.142698625790867 |
#  -> best score yet: [-4.14025925]
# 39 / 60 | current eval : [-1.9611165040675578] / score : -4.14293871023607 |
#  -> best score yet: [-4.14025925]
# 40 / 60 | current eval : [-1.9612239444569777] / score : -4.14172942401332 |
#  -> best score yet: [-4.14025925]
# 41 / 60 | current eval : [1.822247679017747] / score : -8.935437572924805 |
#  -> best score yet: [-4.14025925]
# 42 / 60 | current eval : [-1.9611210802017924] / score : -4.142887113310681 |
#  -> best score yet: [-4.14025925]
# 43 / 60 | current eval : [-1.9611204424455895] / score : -4.142894303669307 |
#  -> best score yet: [-4.14025925]
# 44 / 60 | current eval : [2.930600895792467] / score : -9.524140148239875 |
#  -> best score yet: [-4.14025925]
# 45 / 60 | current eval : [-1.9611193894456864] / score : -4.142906176020384 |
#  -> best score yet: [-4.14025925]
# 46 / 60 | current eval : [-1.9611186286221285] / score : -4.1429147544106915 |
#  -> best score yet: [-4.14025925]
# 47 / 60 | current eval : [-1.9611429776484282] / score : -4.142640326370175 |
#  -> best score yet: [-4.14025925]
# 48 / 60 | current eval : [-1.961115439590605] / score : -4.142950713605103 |
#  -> best score yet: [-4.14025925]
# /anaconda3/lib/python3.7/site-packages/sklearn/gaussian_process/gpr.py:469: ConvergenceWarning: fmin_l_bfgs_b terminated abnormally with the  state: {'grad': array([-4.60002047e-06,  1.18427071e-05]), 'task': b'ABNORMAL_TERMINATION_IN_LNSRCH', 'funcalls': 62, 'nit': 14, 'warnflag': 2}
#   ConvergenceWarning)
# 49 / 60 | current eval : [1.8222459262864286] / score : -8.93553015946206 |
#  -> best score yet: [-4.14025925]
# 50 / 60 | current eval : [-4.18558718138345] / score : -23.58154745726232 |
#  -> best score yet: [-4.14025925]
# 51 / 60 | current eval : [1.822246971892796] / score : -8.935474926132597 |
#  -> best score yet: [-4.14025925]
# 52 / 60 | current eval : [-1.9611220569902037] / score : -4.14287610084965 |
#  -> best score yet: [-4.14025925]
# 53 / 60 | current eval : [1.822242715468726] / score : -8.935699769564541 |
#  -> best score yet: [-4.14025925]
# 54 / 60 | current eval : [-1.9611206798971192] / score : -4.142891626512553 |
#  -> best score yet: [-4.14025925]
# 55 / 60 | current eval : [2.9307049731409998] / score : -9.521990145909088 |
#  -> best score yet: [-4.14025925]
# 56 / 60 | current eval : [1.822242811276424] / score : -8.935694708536829 |
#  -> best score yet: [-4.14025925]
# 57 / 60 | current eval : [-1.9611173523706655] / score : -4.142929144822103 |
#  -> best score yet: [-4.14025925]
# 58 / 60 | current eval : [-1.961122966771605] / score : -4.142865844166287 |
#  -> best score yet: [-4.14025925]
# 59 / 60 | current eval : [-1.9611189117271512] / score : -4.142911562336565 |
#  -> best score yet: [-4.14025925]
